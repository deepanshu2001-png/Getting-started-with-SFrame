# %%
import graphlab

# %%
# loading SFrame dataset
sf = graphlab.SFrame("datasets_494724_1426184_COVID19_line_list_data.csv")
# Out:
# Finished parsing file C:\Users\prateek\datasets_494724_1426184_COVID19_line_list_data.csv
# Parsing completed. Parsed 100 lines in 0.046974 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[long,str,str,str,str,str,str,str,long,str,long,str,str,str,long,long,long,long,str,str,str,str,str,str,str,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file C:\Users\prateek\datasets_494724_1426184_COVID19_line_list_data.csv
# Parsing completed. Parsed 1085 lines in 0.048971 secs.

# %%
#to view data
sf
# Out:
# Columns:
# 	﻿id	int
# 	case_in_country	str
# 	reporting date	str
# 	X4	str
# 	summary	str
# 	location	str
# 	country	str
# 	gender	str
# 	age	int
# 	symptom_onset	str
# 	If_onset_approximated	int
# 	hosp_visit_date	str
# 	exposure_start	str
# 	exposure_end	str
# 	visiting Wuhan	int
# 	from Wuhan	int
# 	death	int
# 	recovered	int
# 	symptom	str
# 	source	str
# 	link	str
# 	.1	str
# 	.2	str
# 	.3	str
# 	.4	str
# 	.5	str
# 	.6	str
#
# Rows: 1085
#
# Data:
# +-----+-----------------+----------------+----+-------------------------------+
# | ﻿id | case_in_country | reporting date | X4 |            summary            |
# +-----+-----------------+----------------+----+-------------------------------+
# |  1  |                 |   1/20/2020    |    | First confirmed imported C... |
# |  2  |                 |   1/20/2020    |    | First confirmed imported C... |
# |  3  |                 |   1/21/2020    |    | First confirmed imported c... |
# ...

# %%
sf.head()
# Out:
# Columns:
# 	﻿id	int
# 	case_in_country	str
# 	reporting date	str
# 	X4	str
# 	summary	str
# 	location	str
# 	country	str
# 	gender	str
# 	age	int
# 	symptom_onset	str
# 	If_onset_approximated	int
# 	hosp_visit_date	str
# 	exposure_start	str
# 	exposure_end	str
# 	visiting Wuhan	int
# 	from Wuhan	int
# 	death	int
# 	recovered	int
# 	symptom	str
# 	source	str
# 	link	str
# 	.1	str
# 	.2	str
# 	.3	str
# 	.4	str
# 	.5	str
# 	.6	str
#
# Rows: 10
#
# Data:
# +-----+-----------------+----------------+----+-------------------------------+
# | ﻿id | case_in_country | reporting date | X4 |            summary            |
# +-----+-----------------+----------------+----+-------------------------------+
# |  1  |                 |   1/20/2020    |    | First confirmed imported C... |
# |  2  |                 |   1/20/2020    |    | First confirmed imported C... |
# |  3  |                 |   1/21/2020    |    | First confirmed imported c... |
# ...

# %%
# last lines of data
sf.tail()
# Out:
# Columns:
# 	﻿id	int
# 	case_in_country	str
# 	reporting date	str
# 	X4	str
# 	summary	str
# 	location	str
# 	country	str
# 	gender	str
# 	age	int
# 	symptom_onset	str
# 	If_onset_approximated	int
# 	hosp_visit_date	str
# 	exposure_start	str
# 	exposure_end	str
# 	visiting Wuhan	int
# 	from Wuhan	int
# 	death	int
# 	recovered	int
# 	symptom	str
# 	source	str
# 	link	str
# 	.1	str
# 	.2	str
# 	.3	str
# 	.4	str
# 	.5	str
# 	.6	str
#
# Rows: 10
#
# Data:
# +------+-----------------+----------------+----+-------------------------------+
# | ﻿id  | case_in_country | reporting date | X4 |            summary            |
# +------+-----------------+----------------+----+-------------------------------+
# | 1076 |        14       |   2/25/2020    |    | new COVID-19 patient confi... |
# | 1077 |        15       |   2/25/2020    |    | new COVID-19 patient confi... |
# | 1078 |        16       |   2/25/2020    |    | new COVID-19 patient confi... |
# ...

# %%
# Graphlab canvas
## take any datset in graphlab
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:50227/index.html
# Opening Canvas in default web browser.

# %%
graphlab.canvas.set_target("ipynb")

# %%
sf["age"].show(view="Categorical")

# %%
sf["location"]
# Out:
# dtype: str
# Rows: 1085
# ...

# %%
sf["age"]
# Out:
# dtype: int
# Rows: 1085
# [66L, 56L, 46L, 60L, 58L, 44L, 34L, 37L, 39L, 56L, 18L, 32L, 37L, 51L, 57L, 56L, 50L, 52L, 33L, 40L, 70L, 51L, None, 28L, 37L, 19L, 29L, 66L, 46L, 32L, 28L, 55L, 68L, 38L, 72L, 45L, 42L, 33L, 33L, 37L, 69L, 63L, 62L, 49L, 50L, 48L, 36L, 36L, 61L, 69L, 89L, 89L, 66L, 75L, 48L, 82L, 66L, 81L, 82L, 65L, 80L, 53L, 86L, 70L, 84L, 50L, 40L, 45L, 66L, 59L, 23L, 50L, 43L, 49L, 42L, 32L, 22L, 47L, 52L, 53L, 46L, 85L, 69L, 36L, 73L, 70L, 81L, 65L, 42L, 30L, 29L, None, 49L, 23L, 56L, 39L, 39L, 34L, 49L, 70L, ... ]

# %%
sf["age"].mean()
# Out:
# 49.482799525504134

# %%
sf["age"].max()
# Out:
# 96L

# %%
sf["Country location"] = sf["location"] + ' ' + sf["country"]

# %%
sf
# Out:
# Columns:
# 	﻿id	int
# 	case_in_country	str
# 	reporting date	str
# 	X4	str
# 	summary	str
# 	location	str
# 	country	str
# 	gender	str
# 	age	int
# 	symptom_onset	str
# 	If_onset_approximated	int
# 	hosp_visit_date	str
# 	exposure_start	str
# 	exposure_end	str
# 	visiting Wuhan	int
# 	from Wuhan	int
# 	death	int
# 	recovered	int
# 	symptom	str
# 	source	str
# 	link	str
# 	.1	str
# 	.2	str
# 	.3	str
# 	.4	str
# 	.5	str
# 	.6	str
# 	Country location	str
#
# Rows: 1085
#
# Data:
# +-----+-----------------+----------------+----+-------------------------------+
# | ﻿id | case_in_country | reporting date | X4 |            summary            |
# +-----+-----------------+----------------+----+-------------------------------+
# |  1  |                 |   1/20/2020    |    | First confirmed imported C... |
# |  2  |                 |   1/20/2020    |    | First confirmed imported C... |
# |  3  |                 |   1/21/2020    |    | First confirmed imported c... |
# ...

# %%
sf['age'] + 2
# Out:
# dtype: int
# Rows: 1085
# [68L, 58L, 48L, 62L, 60L, 46L, 36L, 39L, 41L, 58L, 20L, 34L, 39L, 53L, 59L, 58L, 52L, 54L, 35L, 42L, 72L, 53L, None, 30L, 39L, 21L, 31L, 68L, 48L, 34L, 30L, 57L, 70L, 40L, 74L, 47L, 44L, 35L, 35L, 39L, 71L, 65L, 64L, 51L, 52L, 50L, 38L, 38L, 63L, 71L, 91L, 91L, 68L, 77L, 50L, 84L, 68L, 83L, 84L, 67L, 82L, 55L, 88L, 72L, 86L, 52L, 42L, 47L, 68L, 61L, 25L, 52L, 45L, 51L, 44L, 34L, 24L, 49L, 54L, 55L, 48L, 87L, 71L, 38L, 75L, 72L, 83L, 67L, 44L, 32L, 31L, None, 51L, 25L, 58L, 41L, 41L, 36L, 51L, 72L, ... ]

# %%
sf['age'] * sf['age']
# Out:
# dtype: int
# Rows: 1085
# [4356L, 3136L, 2116L, 3600L, 3364L, 1936L, 1156L, 1369L, 1521L, 3136L, 324L, 1024L, 1369L, 2601L, 3249L, 3136L, 2500L, 2704L, 1089L, 1600L, 4900L, 2601L, None, 784L, 1369L, 361L, 841L, 4356L, 2116L, 1024L, 784L, 3025L, 4624L, 1444L, 5184L, 2025L, 1764L, 1089L, 1089L, 1369L, 4761L, 3969L, 3844L, 2401L, 2500L, 2304L, 1296L, 1296L, 3721L, 4761L, 7921L, 7921L, 4356L, 5625L, 2304L, 6724L, 4356L, 6561L, 6724L, 4225L, 6400L, 2809L, 7396L, 4900L, 7056L, 2500L, 1600L, 2025L, 4356L, 3481L, 529L, 2500L, 1849L, 2401L, 1764L, 1024L, 484L, 2209L, 2704L, 2809L, 2116L, 7225L, 4761L, 1296L, 5329L, 4900L, 6561L, 4225L, 1764L, 900L, 841L, None, 2401L, 529L, 3136L, 1521L, 1521L, 1156L, 2401L, 4900L, ... ]
